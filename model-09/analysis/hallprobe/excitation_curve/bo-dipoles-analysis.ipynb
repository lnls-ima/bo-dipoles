# %%
import lnls.hallprobe as hp
import matplotlib.pyplot as plt

# %matplotlib notebook


currlabels0 = ('0040p31A', '0050p39A', '0060p46A', '0165p27A',
               '0330p54A', '0500p00A', '0640p00A', '0680p00A',
               '0720p00A', '0800p00A', '0942p05A', '0991p63A', '1041p21A')

magnets = {
    'bd-006': currlabels0,
}

data = hp.DipolesSetBO('x0-9p1013mm', magnets)

# %%
plt.figure()
data.plot_energies(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data.plot_angles(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data.plot_quadrupoles(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data.plot_sextupoles(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
